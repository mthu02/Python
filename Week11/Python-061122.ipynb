# %% [markdown]
# Ngo Thi Minh Thu
#
# PTDL55

# %%
pieces = []
columns = ["ALP","ALT","AST","Albumin","BUN","Bilirubin","Cholesterol","Creatinine","DiasABP","FiO2","GCS","Glucose","HCO3","HCT","HR","K","Lactate","MAP","Mg","Na","PaCO2","PaO2","Platelets","RespRate","SaO2","SysABP","Temp","Tropl","TroponinI","TropT","TroponinT","Urine","WBC","pH","NIDiasABP","NIMAP","NISysABP","MechVent","RecordID","Age","Gender","ICUType","Height","Weight"]

# %%
import glob 
import pandas as pd
import matplotlib.pyplot as plt
path = 'C:/Users/ADMIN/Desktop/Python/data'
files = glob.glob(path+"/*.txt")
df_ = (pd.read_csv(file) for file in files)
df = pd.concat(df_)
df
# Out:
#       Time  Parameter     Value
# 0    00:00   RecordID  132539.0
# 1    00:00        Age      54.0
# 2    00:00     Gender       0.0
# 3    00:00     Height      -1.0
# 4    00:00    ICUType       4.0
# ..     ...        ...       ...
# 412  47:45  NIDiasABP      59.0
# 413  47:45      NIMAP      71.0
# 414  47:45   NISysABP     110.0
# 415  47:45       Temp      37.0
# 416  47:45      Urine      30.0
#
# [24903 rows x 3 columns]

# %%
def plot(df,attr):
    fig = plt.figure(figsize=(10,4))

    ax1 = fig.add_subplot(121)
    ax1.hist(df)
    ax1.set_title('Histogram about ({})'.format(attr))

    dfxx = df.describe().to_frame().round(2)

    ax2 = fig.add_subplot(122)
    font_size=12
    bbox=[0, 0, 1, 1]
    ax2.axis('off')
    mpl_table = ax2.table(cellText = dfxx.values, rowLabels = dfxx.index, bbox=bbox, colLabels=dfxx.columns)
    mpl_table.auto_set_font_size(False)
    mpl_table.set_fontsize(font_size)

# %%
dfx=[]
for c in columns:
    d = df[df["Parameter"]==c]["Value"]
    dfx.append(d)

# %%
idx = 0
for dfx_ in dfx:
    plot(dfx_, columns[idx])
    idx+=1
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_4204/1291969060.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=(10,4))
