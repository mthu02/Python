# %% [markdown]
# ## <img src ='Pic\logo.jpg' width='700px'>
#
#
# <div align="center">
#
# # KHÓA HỌC: LẬP TRÌNH PYTHON CƠ BẢN
#
# </div>
#
# -----
# Practice 6 - Phân tích và xử lý dữ liệu với Pandas - Phần 01
# ----
# Họ và tên học viên:
#
# Email:

# %% [markdown]
# ## THỰC HÀNH SỐ 1
# ---
# **Yêu cầu 1.1: Học viên đọc dữ liệu dạng CSV lưu trong file Data_Loan.csv với các tham số mặc định, cho biết các thông tin cơ bản của file**

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}
import pandas as pd
data = pd.read_csv('Data_Practice6/Data_Loan.csv')

# %%
data.head()
# Out:
#    loan_amnt       term  int_rate  emp_length home_ownership  annual_inc  \
# 0       5000  36 months     10.65        10.0           RENT     24000.0
# 1       2500  60 months     15.27         0.0           RENT     30000.0
# 2       2400  36 months     15.96        10.0           RENT     12252.0
# 3      10000  36 months     13.49        10.0           RENT     49200.0
# 4       5000  36 months      7.90         3.0           RENT     36000.0
#
#           purpose addr_state    dti  delinq_2yrs  revol_util  total_acc  \
# 0     credit_card         AZ  27.65          0.0        83.7        9.0
# 1             car         GA   1.00          0.0         9.4        4.0
# 2  small_business         IL   8.72          0.0        98.5       10.0
# 3           other         CA  20.00          0.0        21.0       37.0
# 4         wedding         AZ  11.20          0.0        28.3       12.0
#
#    bad_loan  longest_credit_length verification_status
# 0         0                   26.0            verified
# 1         1                   12.0            verified
# 2         0                   10.0        not verified
# 3         0                   15.0            verified
# 4         0                    7.0            verified

# %%
data.describe()
# Out:
#            loan_amnt       int_rate     emp_length    annual_inc  \
# count  163987.000000  163987.000000  158183.000000  1.639830e+05
# mean    13074.169141      13.715904       5.684353  7.191567e+04
# std      7993.556189       4.391940       3.610664  5.907092e+04
# min       500.000000       5.420000       0.000000  1.896000e+03
# 25%      7000.000000      10.650000       2.000000  4.500000e+04
# 50%     11325.000000      13.490000       6.000000  6.100000e+04
# 75%     18000.000000      16.320000      10.000000  8.500000e+04
# max     35000.000000      26.060000      10.000000  7.141778e+06
#
#                  dti    delinq_2yrs     revol_util      total_acc  \
# count  163987.000000  163958.000000  163794.000000  163958.000000
# mean       15.881530       0.227357      54.079173      24.579734
# std         7.587668       0.694168      25.285367      11.685190
# min         0.000000       0.000000       0.000000       1.000000
# 25%        10.230000       0.000000      35.600000      16.000000
# 50%        15.620000       0.000000      55.800000      23.000000
# 75%        21.260000       0.000000      74.200000      31.000000
# max        39.990000      29.000000     150.700000     118.000000
#
#             bad_loan  longest_credit_length
# count  163987.000000          163958.000000
# mean        0.183039              14.854274
# std         0.386700               6.947733
# min         0.000000               0.000000
# 25%         0.000000              10.000000
# 50%         0.000000              14.000000
# 75%         0.000000              18.000000
# max         1.000000              65.000000

# %% [markdown]
# **Yêu cầu 1.2: Đọc dữ liệu từ file Data_Loan.CSV vào 2 biến DataFrame tương ứng**
# 1. df_number: Chỉ chứa các cột dữ liệu số
# 2. df_object: Chỉ chứa các cột dữ liệu Object

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}
df_number = data.select_dtypes('number')
df_object = data.select_dtypes('object')

# %%
df_number.head()
# Out:
#    loan_amnt  int_rate  emp_length  annual_inc    dti  delinq_2yrs  \
# 0       5000     10.65        10.0     24000.0  27.65          0.0
# 1       2500     15.27         0.0     30000.0   1.00          0.0
# 2       2400     15.96        10.0     12252.0   8.72          0.0
# 3      10000     13.49        10.0     49200.0  20.00          0.0
# 4       5000      7.90         3.0     36000.0  11.20          0.0
#
#    revol_util  total_acc  bad_loan  longest_credit_length
# 0        83.7        9.0         0                   26.0
# 1         9.4        4.0         1                   12.0
# 2        98.5       10.0         0                   10.0
# 3        21.0       37.0         0                   15.0
# 4        28.3       12.0         0                    7.0

# %%
df_object.head()
# Out:
#         term home_ownership         purpose addr_state verification_status
# 0  36 months           RENT     credit_card         AZ            verified
# 1  60 months           RENT             car         GA            verified
# 2  36 months           RENT  small_business         IL        not verified
# 3  36 months           RENT           other         CA            verified
# 4  36 months           RENT         wedding         AZ            verified

# %% [markdown]
# **Yêu cầu 1.3: Đọc dữ liệu nhiệt độ của 6 thành phố [Hà Nội, Vinh, Đà Nẵng, Nha Trang, TP Hồ Chí Minh, Cà Mau] từ file txt_Data_Temp.txt vào biến DataFrame tương ứng**

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}
colnames=['Hà Nội', 'Vinh', 'Đà Nẵng', 'Nha Trang', 'TP Hồ Chí Minh', 'Cà Mau'] 
data_temp = pd.read_fwf('Data_Practice6/txt_Data_Temp.txt', header=None,names = colnames)

# %%
data_temp.head()
# Out:
#    Hà Nội   Vinh  Đà Nẵng  Nha Trang  TP Hồ Chí Minh  Cà Mau
# 0   25.65  24.79    24.01      25.06           25.48   24.97
# 1   25.31  24.21    24.02      24.93           25.16   24.83
# 2   25.05  23.73    23.89      24.79           24.80   24.55
# 3   24.79  23.36    23.83      24.84           24.74   24.48
# 4   24.59  23.05    23.69      24.82           24.80   24.38

# %% [markdown]
# ## THỰC HÀNH SỐ 2:
# ---
# Yêu cầu: Học viên đọc dữ liệu dạng excel lưu trong file excel_Data_Movies.xls theo từng sheet

# %%
#{HỌC VIÊN VIẾT CODE Ở ĐÂY}
df_sheet_0 = pd.read_excel('Data_Practice6/excel_Data_Movies.xls', sheet_name=0)
df_sheet_1 = pd.read_excel('Data_Practice6/excel_Data_Movies.xls', sheet_name='2000s')
df_sheet_2 = pd.read_excel('Data_Practice6/excel_Data_Movies.xls', sheet_name='2010s')

# %%
df_sheet_0.head()
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated       123
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110
#
#    Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0          1.33   385907.0             NaN  ...                      436
# 1          1.33   100000.0       3000000.0  ...                        2
# 2          1.33   245000.0             NaN  ...                       81
# 3          1.33  6000000.0         26435.0  ...                      136
# 4          1.33        NaN          9950.0  ...                      426
#
#   Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 0                       22                      9.0
# 1                        2                      0.0
# 2                       12                      6.0
# 3                       23                     18.0
# 4                       20                      3.0
#
#   Facebook Likes - cast Total  Facebook likes - Movie  Facenumber in posters  \
# 0                         481                     691                      1
# 1                           4                       0                      1
# 2                         108                     226                      0
# 3                         203                   12000                      1
# 4                         455                     926                      1
#
#    User Votes  Reviews by Users  Reviews by Crtiics  IMDB Score
# 0       10718                88                69.0         8.0
# 1           5                 1                 1.0         4.8
# 2        4849                45                48.0         8.3
# 3      111841               413               260.0         8.3
# 4        7431                84                71.0         8.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ## THỰC HÀNH SỐ 3:
# ---
# **Mô tả file dữ liệu: Data_Patient.csv**
# * File dữ liệu chứa thông tin của 300 bệnh nhân bị chứng đau ngực
# * Mỗi dòng ứng với thông tin của một bệnh nhân, bao gồm 9 thuộc tính.
#
# **Chi tiết thông tin của một bệnh nhân như sau:**
# * id: Mã của bệnh nhân (số)
# * Feature_1: Tuổi của bệnh nhân (số)
# * Feature_2: Giới tính của bệnh nhân (chuỗi: Male – Female)
# * Feature_3: Cho biết loại triệu chứng đau ngực mà bệnh nhân này mắc phải, với 4 giá trị: (Typical angina, Atypical angina, Non-anginal pain, Asymptomatic)
# * Feature_4: Huyết áp của bệnh nhân – đơn vị: mmhg (số)
# * Feature_5: Chỉ số cholesterol của bệnh nhân – đơn vị: mg/dl (số)
# * Feature_6: Thông số nhịp tim của bệnh nhân – đơn vị: lần/phút (số)
# * Feature_7: Chỉ số Thalassemia của bệnh nhân chỉ gồm 3 giá trị (3: Bình thường | 4: Khiếm khuyết cố định | 7: Kiếm khuyết có thể đảo ngược)
# * Feature_8: Cho biết bệnh nhân có bị bệnh tim hay không? (0: Không bị bệnh tim mạch | 1: Bị bệnh tim mạch)

# %% [markdown]
# **Yêu cầu 3.1:**
# 1. Đọc dữ liệu từ file Data_Excercise\Data_patient.csv vào biến kiểu dataframe: df_patient với cột đầu tiên (id) là cột chỉ số (index_col)
# 2. Hiển thị thông tin tổng quan của tập dữ liệu
# 3. Hiển thị thông tin của 10 bệnh nhân đầu tiên và 5 bệnh nhân cuối cùng của tập dữ liệu.
# 4. Đặt lại tên các cột dữ liệu trong Dataframe:
#     * Feature_1 --> Age
#     * Feature_2 --> Gender
#     * Feature_3 --> Type
#     * Feature_4 --> Blood_pressure
#     * Feature_5 --> Cholesterol
#     * Feature_6 --> Heartbeat
#     * Feature_7 --> Thalassemia
#     * Feature_8 --> Result

# %%
#{VIẾT CODE CỦA BẠN VÀO ĐÂY}
df_patient = pd.read_csv('Data_Practice6/Data_Patient.csv',index_col='id')

# %%
df_patient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, Patient_01 to Patient_300
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             300 non-null    int64
#  1   Gender          300 non-null    object
#  2   Type            295 non-null    object
#  3   Blood_pressure  300 non-null    int64
#  4   Cholesterol     300 non-null    int64
#  5   Heartbeat       300 non-null    int64
#  6   Thalassemia     293 non-null    float64
#  7   Result          300 non-null    int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 21.1+ KB

# %%
df_patient.head(10)
# Out:
#             feature_1 feature_2         feature_3  feature_4  feature_5  \
# id
# Patient_01         63      Male    Typical angina        145        233
# Patient_02         67      Male      Asymptomatic        160        286
# Patient_03         67      Male      Asymptomatic        120        229
# Patient_04         37      Male  Non-anginal pain        130        250
# Patient_05         41    Female   Atypical angina        130        204
# Patient_06         56      Male   Atypical angina        120        236
# Patient_07         62    Female      Asymptomatic        140        268
# Patient_08         57    Female      Asymptomatic        120        354
# Patient_09         63      Male      Asymptomatic        130        254
# Patient_10         53      Male      Asymptomatic        140        203
#
#             feature_6  feature_7  feature_8
# id
# Patient_01        150        6.0          0
# Patient_02        108        3.0          1
# Patient_03        129        7.0          1
# Patient_04        187        3.0          0
# Patient_05        172        NaN          0
# Patient_06        178        3.0          0
# Patient_07        160        3.0          1
# Patient_08        163        3.0          0
# Patient_09        147        7.0          1
# Patient_10        155        7.0          1

# %%
df_patient.tail()
# Out:
#              feature_1 feature_2       feature_3  feature_4  feature_5  \
# id
# Patient_296         59      Male    Asymptomatic        164        176
# Patient_297         57    Female    Asymptomatic        140        241
# Patient_298         45      Male  Typical angina        110        264
# Patient_299         68      Male    Asymptomatic        144        193
# Patient_300         57      Male    Asymptomatic        130        131
#
#              feature_6  feature_7  feature_8
# id
# Patient_296         90        6.0          1
# Patient_297        123        7.0          1
# Patient_298        132        7.0          1
# Patient_299        141        7.0          1
# Patient_300        115        7.0          1

# %%
df_patient = df_patient.rename(columns={'feature_1':'Age','feature_2':'Gender','feature_3':'Type','feature_4':'Blood_pressure','feature_5':'Cholesterol','feature_6':'Heartbeat','feature_7':'Thalassemia','feature_8':'Result'})

# %% [markdown]
# **Yêu cầu 3.2:**
# Sử dụng phương thức .describe() cho biết:
#
#     * Thuộc tính Age:
#         - Tuổi của bệnh nhân trẻ nhất
#         - Tuổi của bệnh nhân già nhất
#     * Thuộc tính Cholesterol:
#         - Cholesterol trung bình của các bệnh nhân
#         - Độ lệch chuẩn của giá trị này trong toàn bộ tập dữ liệu
#     * Bao nhiêu bệnh nhân giới tính nam (Male)
#     * Có bao nhiêu giá trị khác nhau của thuộc tính Type. Giá trị xuất hiện nhiều nhất là giá trị nào, bao nhiêu lần.

# %%
#{VIẾT CODE CỦA BẠN VÀO ĐÂY}
df_patient.describe().applymap(lambda x: f"{x:0.0f}")
# Out:
#        Age Blood_pressure Cholesterol Heartbeat Thalassemia Result
# count  300            300         300       300         293    300
# mean    54            132         247       150           5      0
# std      9             18          52        23           2      0
# min     29             94         126        71           3      0
# 25%     48            120         211       134           3      0
# 50%     56            130         242       152           3      0
# 75%     61            140         275       165           7      1
# max     77            200         564       202           7      1

# %%
include =['object']
desc = df_patient.describe( include = include)
desc
# Out:
#        Gender          Type
# count     300           295
# unique      2             4
# top      Male  Asymptomatic
# freq      205           139

# %% [markdown]
# **Yêu cầu 3.3:**
#
# Cho biết những cột nào trong dữ liệu có chứa missing data và số lượng missing là bao nhiêu?

# %%
#{VIẾT CODE CỦA BẠN VÀO ĐÂY}
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
missing= missing_values_table(df_patient)
missing
# Out:
# Your selected dataframe has 8 columns.
# There are 2 columns that have missing values.
#              Missing Values  % of Total Values
# Thalassemia               7                2.3
# Type                      5                1.7

# %% [markdown]
# **Yêu cầu 3.4:**
# Hiển thị thông tin của các bệnh nhân:
#    * Bệnh nhân có index: Patient_100; Patient_150; Patient_200
#    * Bệnh nhân ở vị trí 255 đến 260, với 3 thuộc tính: Age, Gender và Result

# %%
#{VIẾT CODE CỦA BẠN VÀO ĐÂY}
df_patient.loc[["Patient_100","Patient_150","Patient_200"]]
# Out:
#              Age  Gender            Type  Blood_pressure  Cholesterol  \
# id
# Patient_100   45    Male    Asymptomatic             115          260
# Patient_150   52    Male  Typical angina             152          298
# Patient_200   50  Female    Asymptomatic             110          254
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_100        185          3.0       0
# Patient_150        178          7.0       0
# Patient_200        159          3.0       0

# %%
df_patient[['Age','Gender','Result']].loc["Patient_255":"Patient_260"]
# Out:
#              Age  Gender  Result
# id
# Patient_255   42  Female       0
# Patient_256   67  Female       0
# Patient_257   76  Female       0
# Patient_258   70    Male       0
# Patient_259   57    Male       1
# Patient_260   44  Female       0

# %% [markdown]
# **Yêu cầu 3.5:**
# 1. Thay đổi giá trị cho thuộc tính Gender: Male --> 0, Female --> 1
# 2. Thay đổi giá trị cho thuộc tính Result: 0 --> No, 1 --> Yes
# 3. Cập nhật giá trị thuộc tính Thalassemia của bệnh nhân có index: Patient_05 bằng giá trị 4.0

# %%
#{VIẾT CODE CỦA BẠN VÀO ĐÂY}
df_patient.loc[df_patient['Gender']=='Male','Gender']=0
df_patient.loc[df_patient['Gender']=='Female','Gender']=1

# %%
df_patient.loc[df_patient['Result']==0,'Result']= 'No'
df_patient.loc[df_patient['Result']==1, 'Result']= 'Yes'

# %%
df_patient
# Out:
#              Age Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_01    63      0    Typical angina             145          233
# Patient_02    67      0      Asymptomatic             160          286
# Patient_03    67      0      Asymptomatic             120          229
# Patient_04    37      0  Non-anginal pain             130          250
# Patient_05    41      1   Atypical angina             130          204
# ...          ...    ...               ...             ...          ...
# Patient_296   59      0      Asymptomatic             164          176
# Patient_297   57      1      Asymptomatic             140          241
# Patient_298   45      0    Typical angina             110          264
# Patient_299   68      0      Asymptomatic             144          193
# Patient_300   57      0      Asymptomatic             130          131
#
#              Heartbeat  Thalassemia Result
# id
# Patient_01         150          6.0     No
# Patient_02         108          3.0    Yes
# Patient_03         129          7.0    Yes
# Patient_04         187          3.0     No
# Patient_05         172          NaN     No
# ...                ...          ...    ...
# Patient_296         90          6.0    Yes
# Patient_297        123          7.0    Yes
# Patient_298        132          7.0    Yes
# Patient_299        141          7.0    Yes
# Patient_300        115          7.0    Yes
#
# [300 rows x 8 columns]

# %% [markdown]
# # THỰC HÀNH SỐ 4:
# ---
# **Yêu cầu 4.1:**
# 1. Đọc dữ liệu từ file Data_Excercise\Data_patient.csv vào biến kiểu dataframe: df_patient với cột feature_1 là cột chỉ số (index_col)
# 2. Đặt lại tên các cột dữ liệu trong Dataframe:
#     * Feature_1 --> Age
#     * Feature_2 --> Gender
#     * Feature_3 --> Type
#     * Feature_4 --> Blood_pressure
#     * Feature_5 --> Cholesterol
#     * Feature_6 --> Heartbeat
#     * Feature_7 --> Thalassemia
#     * Feature_8 --> Result
#
#  *Như yêu cầu đã thực hiện trong bài thực hành số 3*

# %%
#{VIẾT CODE CỦA BẠN VÀO ĐÂY}
df_patient = pd.read_csv('Data_Practice6/Data_Patient.csv',index_col='id')

# %%
df_patient = df_patient.rename(columns={'feature_1':'Age','feature_2':'Gender','feature_3':'Type','feature_4':'Blood_pressure','feature_5':'Cholesterol','feature_6':'Heartbeat','feature_7':'Thalassemia','feature_8':'Result'})
df_patient.head()
# Out:
#             Age  Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_01   63    Male    Typical angina             145          233
# Patient_02   67    Male      Asymptomatic             160          286
# Patient_03   67    Male      Asymptomatic             120          229
# Patient_04   37    Male  Non-anginal pain             130          250
# Patient_05   41  Female   Atypical angina             130          204
#
#             Heartbeat  Thalassemia  Result
# id
# Patient_01        150          6.0       0
# Patient_02        108          3.0       1
# Patient_03        129          7.0       1
# Patient_04        187          3.0       0
# Patient_05        172          NaN       0

# %% [markdown]
# **Yêu cầu 4.2:**
# Lọc dữ liệu trong df_patient thành các DataFrame:
#     * df_male: chứa danh sách bệnh nhân Nam
#     * df_female: chứa danh sách bệnh nhân nữ
#     * df_no: danh sách những người không bị bệnh đau tim
#     * df_yes: danh sách những người bị bệnh đau tim

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}
df_male = df_patient.loc[df_patient['Gender']=='Male']
df_female = df_patient.loc[df_patient['Gender']=='Female']
df_no = df_patient.loc[df_patient['Result']==0]
df_yes = df_patient.loc[df_patient['Result']==1]

# %%
df_male
# Out:
#              Age Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_01    63   Male    Typical angina             145          233
# Patient_02    67   Male      Asymptomatic             160          286
# Patient_03    67   Male      Asymptomatic             120          229
# Patient_04    37   Male  Non-anginal pain             130          250
# Patient_06    56   Male   Atypical angina             120          236
# ...          ...    ...               ...             ...          ...
# Patient_295   41   Male   Atypical angina             120          157
# Patient_296   59   Male      Asymptomatic             164          176
# Patient_298   45   Male    Typical angina             110          264
# Patient_299   68   Male      Asymptomatic             144          193
# Patient_300   57   Male      Asymptomatic             130          131
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_01         150          6.0       0
# Patient_02         108          3.0       1
# Patient_03         129          7.0       1
# Patient_04         187          3.0       0
# Patient_06         178          3.0       0
# ...                ...          ...     ...
# Patient_295        182          3.0       0
# Patient_296         90          6.0       1
# Patient_298        132          7.0       1
# Patient_299        141          7.0       1
# Patient_300        115          7.0       1
#
# [205 rows x 8 columns]

# %%
df_female
# Out:
#              Age  Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_05    41  Female   Atypical angina             130          204
# Patient_07    62  Female      Asymptomatic             140          268
# Patient_08    57  Female      Asymptomatic             120          354
# Patient_12    56  Female   Atypical angina             140          294
# Patient_19    48  Female  Non-anginal pain             130          275
# ...          ...     ...               ...             ...          ...
# Patient_282   55  Female      Asymptomatic             128          205
# Patient_286   58  Female      Asymptomatic             170          225
# Patient_291   55  Female   Atypical angina             132          342
# Patient_294   63  Female      Asymptomatic             124          197
# Patient_297   57  Female      Asymptomatic             140          241
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_05         172          NaN       0
# Patient_07         160          3.0       1
# Patient_08         163          3.0       0
# Patient_12         153          3.0       0
# Patient_19         139          3.0       0
# ...                ...          ...     ...
# Patient_282        130          7.0       1
# Patient_286        146          6.0       1
# Patient_291        166          3.0       0
# Patient_294        136          NaN       1
# Patient_297        123          7.0       1
#
# [95 rows x 8 columns]

# %% [markdown]
# **Yêu cầu 4.3:**
# Lọc trong df_patient dưa ra danh sách bệnh nhân thỏa mãn yêu cầu sau:
# 1. Những người bị mắc bệnh đau tim và trên 70 tuổi
# 2. Người có giới tính Female, có huyết áp trên 170 mmhg nhưng không bị bệnh đau tim.
# 3. Những người có triệu chứng đau ngực là Typical angina, giới tính Male và bị bệnh đau tim.

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}
df_1 = df_patient.loc[(df_patient['Result']==1) & (df_patient['Age']>70)]
df_2 = df_patient.loc[(df_patient['Gender']=='Female') & (df_patient['Blood_pressure']>170) & (df_patient['Result'] == 0)]
df_3 = df_patient.loc[(df_patient['Type'] == 'Typical angina') & (df_patient['Gender'] == 'Male') & (df_patient['Result'] == 1)]

# %%
df_3
# Out:
#              Age Gender            Type  Blood_pressure  Cholesterol  \
# id
# Patient_124   65   Male  Typical angina             138          282
# Patient_141   59   Male  Typical angina             170          288
# Patient_199   59   Male  Typical angina             160          273
# Patient_211   38   Male  Typical angina             120          231
# Patient_243   61   Male  Typical angina             134          234
# Patient_274   59   Male  Typical angina             134          204
# Patient_298   45   Male  Typical angina             110          264
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_124        174          3.0       1
# Patient_141        159          7.0       1
# Patient_199        125          3.0       1
# Patient_211        182          7.0       1
# Patient_243        145          3.0       1
# Patient_274        162          3.0       1
# Patient_298        132          7.0       1

# %% [markdown]
# **Yêu cầu 4.4:** Xác định:
# 1. Chỉ số huyết áp (Blood_pressure) thấp nhất, cao nhất, trung bình, trung vị và độ lệch chuẩn của tập dữ liệu
# 2. Chỉ số nhịp tim (Heartbeat) thấp nhất, cao nhất, trung bình, trung vị và độ lệch chuẩn của tập dữ liệu

# %%
#{HỌC VIEN VIẾT CODE VÀO ĐÂY}
df_patient['Blood_pressure'].min()
df_patient['Blood_pressure'].max()
df_patient['Blood_pressure'].mean()
df_patient['Blood_pressure'].median()
df_patient['Blood_pressure'].std()
# Out:
# 17.682497692285477

# %%
df_patient['Heartbeat'].min()
df_patient['Heartbeat'].max()
df_patient['Heartbeat'].mean()
df_patient['Heartbeat'].median()
df_patient['Heartbeat'].std()
# Out:
# 22.818595118151098

# %% [markdown]
# **Yêu cầu 4.5: Xác định:**
# 1. Số giá trị khác nhau của thuộc tính Type
# 2. Vẽ đồ thị dạng cột thể hiện kết quả thống kê số lượng theo từng giá trị khác nhau của thuộc tính Type

# %%
#{HỌC VIEN VIẾT CODE VÀO ĐÂY}
unique = df_patient['Type'].unique()
unique
# Out:
# array(['Typical angina', 'Asymptomatic', 'Non-anginal pain',
#        'Atypical angina', nan], dtype=object)

# %%
df_plt = df_patient.groupby('Type')['Age'].count()
df_plt
# Out:
# Type
# Asymptomatic        139
# Atypical angina      49
# Non-anginal pain     84
# Typical angina       23
# Name: Age, dtype: int64

# %%
import matplotlib.pyplot as plt

df_patient.groupby('Type')['Age'].count().plot(kind='bar', title='BIEU DO THONG KE THEO THUOC TINH TYPE')
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Asymptomatic'),
#   Text(1, 0, 'Atypical angina'),
#   Text(2, 0, 'Non-anginal pain'),
#   Text(3, 0, 'Typical angina')])

# %% [markdown]
# ## THỰC HÀNH SỐ 5
# ---
# Dựa vào dữ liệu chuỗi thời gian quan trắc thông số nhiệt độ của Hà Giang và Cà Mau từ năm 2012 đến 2019 (Data_Temperature.csv), sử dụng các kỹ thuật để tìm ra những thông tin từ 2 bộ dữ liệu đó.

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}

df = pd.read_csv('Data_Practice6/Data_Temperature.csv')
df.head()
# Out:
#              TimeVN    HaGiang      CaMau
# 0   2012-08-01 7:00  26.200001  25.400000
# 1  2012-08-01 10:00  31.400000  30.799999
# 2  2012-08-01 13:00  35.099998  30.000000
# 3  2012-08-01 16:00  35.799999  27.700001
# 4  2012-08-01 19:00  30.400000  28.100000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21670 entries, 0 to 21669
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   TimeVN   21670 non-null  object
#  1   HaGiang  21474 non-null  float64
#  2   CaMau    21420 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 508.0+ KB

# %%
df.describe()
# Out:
#             HaGiang         CaMau
# count  21474.000000  21420.000000
# mean      23.786183     27.994659
# std        5.558138      2.485884
# min        1.000000      7.300000
# 25%       19.799999     26.400000
# 50%       24.600000     27.600000
# 75%       27.500000     29.600000
# max       39.000000     36.400002

# %%
missing_values_table(df)
# Out:
# Your selected dataframe has 3 columns.
# There are 2 columns that have missing values.
#          Missing Values  % of Total Values
# CaMau               250                1.2
# HaGiang             196                0.9

# %%
import missingno as msno
msno.bar(df)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df[209:218]
# Out:
#                TimeVN    HaGiang      CaMau
# 209  2012-08-27 10:00  30.500000  29.600000
# 210  2012-08-27 13:00  34.700001  30.900000
# 211  2012-08-27 16:00  35.000000  28.299999
# 212  2012-08-27 19:00        NaN        NaN
# 213  2012-08-27 22:00        NaN        NaN
# 214   2012-08-28 1:00        NaN        NaN
# 215   2012-08-28 4:00        NaN        NaN
# 216   2012-08-28 7:00        NaN        NaN
# 217  2012-08-28 10:00  30.799999  27.100000

# %%
# Interpolate using the linear method
df.interpolate(limit_direction="both",inplace=True)

# %%
df[209:218]
# Out:
#                TimeVN    HaGiang      CaMau
# 209  2012-08-27 10:00  30.500000  29.600000
# 210  2012-08-27 13:00  34.700001  30.900000
# 211  2012-08-27 16:00  35.000000  28.299999
# 212  2012-08-27 19:00  34.300000  28.099999
# 213  2012-08-27 22:00  33.600000  27.900000
# 214   2012-08-28 1:00  32.900000  27.700000
# 215   2012-08-28 4:00  32.199999  27.500000
# 216   2012-08-28 7:00  31.499999  27.300000
# 217  2012-08-28 10:00  30.799999  27.100000

# %%
df['TimeVN'] = df['TimeVN'].apply(pd.to_datetime)
df.set_index('TimeVN',inplace=True)
df.head()
# Out:
#                        HaGiang      CaMau
# TimeVN
# 2012-08-01 07:00:00  26.200001  25.400000
# 2012-08-01 10:00:00  31.400000  30.799999
# 2012-08-01 13:00:00  35.099998  30.000000
# 2012-08-01 16:00:00  35.799999  27.700001
# 2012-08-01 19:00:00  30.400000  28.100000

# %%
df.plot(figsize=(10,6),title='Bieu do bieu dien nhiet do')
# Out:
# <AxesSubplot:title={'center':'Bieu do bieu dien nhiet do'}, xlabel='TimeVN'>

# %%
# Earliest date index location
print('Earliest date index location is: ',df.index.argmin())

# Latest date location
print('Latest date location: ',df.index.argmax())
# Out:
# Earliest date index location is:  0
# Latest date location:  21669

# %% [markdown]
# #### Visualising using KDEs
#
# Summarizing the data with Density plots to see where the mass of the data is located

# %%
import seaborn as sns
sns.kdeplot(df['HaGiang'],shade=True)
# Out:
# <AxesSubplot:xlabel='HaGiang', ylabel='Density'>

# %%
sns.kdeplot(df['CaMau'],shade=True)
# Out:
# <AxesSubplot:xlabel='CaMau', ylabel='Density'>

# %%
df['CaMau'].plot(figsize=(16,8),title='Bien do nhiet o Ca Mau')
# Out:
# <AxesSubplot:title={'center':'Bien do nhiet o Ca Mau'}, xlabel='TimeVN'>

# %%
df.resample('M').agg(["mean", "median", "std"]).head()
# Out:
#               HaGiang                           CaMau
#                  mean     median       std       mean     median       std
# TimeVN
# 2012-08-31  28.581504  27.650000  3.488234  27.967683  27.299999  2.059983
# 2012-09-30  26.113125  25.600000  3.247049  26.436458  26.105556  2.394334
# 2012-10-31  24.335685  23.799999  2.551606  27.762097  27.200000  2.615654
# 2012-11-30  21.313333  21.050000  2.803299  27.976042  27.500000  1.831300
# 2012-12-31  17.803226  17.700001  2.860111  27.913508  27.400000  2.344282

# %%
quarter_hg = df.resample('Q')['HaGiang'].mean()
yearly_hg = df.resample('Y')['HaGiang'].mean()

quarter_cm = df.resample('Q')['CaMau'].mean()
yearly_cm = df.resample('Y')['CaMau'].mean()

# %%
df['HaGiang'].plot(figsize=(16, 5), label="Original")
quarter_hg.plot(label="Quarterly")
yearly_hg.plot(label="Yearly")
plt.legend(fontsize="x-large");

# %%
df['CaMau'].plot(figsize=(16, 5), label="Original")
quarter_cm.plot(label="Quarterly")
yearly_cm.plot(label="Yearly")
plt.legend(fontsize="x-large");
